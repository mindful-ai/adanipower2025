# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import random
from collections import deque

# Define environment
state_size = 1  # The agent's position (0 to 4)
action_size = 2  # Left (-1) or Right (+1)
goal_state = 4
episodes = 1000  # Training episodes

# Hyperparameters
learning_rate = 0.01
gamma = 0.95  # Discount factor
epsilon = 1.0  # Exploration rate
epsilon_min = 0.01
epsilon_decay = 0.99
batch_size = 32
memory_size = 1000

# Build the Q-Network (Simple Neural Network)
def build_model():
    model = keras.Sequential([
        keras.layers.Dense(10, activation="relu", input_shape=(state_size,)),
        keras.layers.Dense(10, activation="relu"),
        keras.layers.Dense(action_size, activation="linear")
    ])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate), loss="mse")
    return model

# Initialize memory and model
memory = deque(maxlen=memory_size)
model = build_model()

# Function to choose an action (Explore or Exploit)
def choose_action(state):
    if np.random.rand() < epsilon:
        return np.random.choice([0, 1])  # Random action (Explore)
    q_values = model.predict(np.array([state]), verbose=0)
    return np.argmax(q_values[0])  # Best action (Exploit)

# Function to train the model
def train_model():
    global epsilon
    if len(memory) < batch_size:
        return
    minibatch = random.sample(memory, batch_size)
    
    states, targets = [], []
    for state, action, reward, next_state, done in minibatch:
        target = reward if done else reward + gamma * np.max(model.predict(np.array([next_state]), verbose=0))
        target_f = model.predict(np.array([state]), verbose=0)
        target_f[0][action] = target
        states.append(state)
        targets.append(target_f[0])
    
    model.train_on_batch(np.array(states), np.array(targets))

    if epsilon > epsilon_min:
        epsilon *= epsilon_decay  # Reduce exploration over time

# Training Loop
for episode in range(episodes):
    state = np.array([0])  # Start at position 0
    done = False
    total_reward = 0

    while not done:
        action = choose_action(state)
        next_state = np.array([max(0, min(4, state[0] + (1 if action == 1 else -1)))])  # Move left (-1) or right (+1)
        reward = 10 if next_state[0] == goal_state else -1  # Reward for reaching goal
        done = next_state[0] == goal_state
        memory.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        train_model()

    print(f"Episode {episode+1}: Total Reward = {total_reward}, Epsilon = {epsilon:.4f}")

# Test the trained agent
state = np.array([0])  # Start at 0
print("\nTrained Agent Path:")
while state[0] != goal_state:
    action = np.argmax(model.predict(np.array([state]), verbose=0))  # Choose best action
    state = np.array([max(0, min(4, state[0] + (1 if action == 1 else -1)))])
    print(f"Moved to {state[0]}")

print("Goal Reached! 🎉")
# Out:
# C:\Users\mindf\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode 1: Total Reward = 7, Epsilon = 1.0000
# Episode 2: Total Reward = -6, Epsilon = 1.0000
# Episode 3: Total Reward = -2, Epsilon = 0.9703
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x000001C632E768E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x000001C632E768E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Episode 4: Total Reward = -12, Epsilon = 0.7700
# Episode 5: Total Reward = 1, Epsilon = 0.6964
# Episode 6: Total Reward = 3, Epsilon = 0.6426
# Episode 7: Total Reward = 3, Epsilon = 0.5930
# Episode 8: Total Reward = 2, Epsilon = 0.5417
# Episode 9: Total Reward = 3, Epsilon = 0.4998
# Episode 10: Total Reward = 1, Epsilon = 0.4520
# Episode 11: Total Reward = 3, Epsilon = 0.4171
# Episode 12: Total Reward = 5, Epsilon = 0.3927
# Episode 13: Total Reward = 3, Epsilon = 0.3624
# Episode 14: Total Reward = 4, Epsilon = 0.3378
# Episode 15: Total Reward = 5, Epsilon = 0.3180
# Episode 16: Total Reward = 3, Epsilon = 0.2934
# Episode 17: Total Reward = 5, Epsilon = 0.2763
# Episode 18: Total Reward = 7, Epsilon = 0.2654
# Episode 19: Total Reward = 6, Epsilon = 0.2524
# Episode 20: Total Reward = 7, Epsilon = 0.2424
# Episode 21: Total Reward = 7, Epsilon = 0.2329
# Episode 22: Total Reward = 7, Epsilon = 0.2237
# Episode 23: Total Reward = 5, Epsilon = 0.2106
# Episode 24: Total Reward = 7, Epsilon = 0.2023
# Episode 25: Total Reward = 5, Epsilon = 0.1905
# Episode 26: Total Reward = 7, Epsilon = 0.1830
# Episode 27: Total Reward = 7, Epsilon = 0.1757
# Episode 28: Total Reward = 7, Epsilon = 0.1688
# Episode 29: Total Reward = 7, Epsilon = 0.1622
# Episode 30: Total Reward = 7, Epsilon = 0.1558
# Episode 31: Total Reward = 7, Epsilon = 0.1496
# Episode 32: Total Reward = 7, Epsilon = 0.1437
# Episode 33: Total Reward = 7, Epsilon = 0.1381
# Episode 34: Total Reward = 7, Epsilon = 0.1326
# Episode 35: Total Reward = 7, Epsilon = 0.1274
# Episode 36: Total Reward = 6, Epsilon = 0.1212
# Episode 37: Total Reward = 7, Epsilon = 0.1164
# Episode 38: Total Reward = 7, Epsilon = 0.1118
# Episode 39: Total Reward = 7, Epsilon = 0.1074
# Episode 40: Total Reward = 6, Epsilon = 0.1021
# Episode 41: Total Reward = 7, Epsilon = 0.0981
# Episode 42: Total Reward = 7, Epsilon = 0.0942
# Episode 43: Total Reward = 7, Epsilon = 0.0905
# Episode 44: Total Reward = 7, Epsilon = 0.0870
# Episode 45: Total Reward = 7, Epsilon = 0.0835
# Episode 46: Total Reward = 7, Epsilon = 0.0802
# Episode 47: Total Reward = 7, Epsilon = 0.0771
# Episode 48: Total Reward = 3, Epsilon = 0.0711
# Episode 49: Total Reward = 7, Epsilon = 0.0683
# Episode 50: Total Reward = 7, Epsilon = 0.0656
# Episode 51: Total Reward = 5, Epsilon = 0.0618
# Episode 52: Total Reward = 7, Epsilon = 0.0594
# Episode 53: Total Reward = 7, Epsilon = 0.0570
# Episode 54: Total Reward = 3, Epsilon = 0.0526
# Episode 55: Total Reward = 7, Epsilon = 0.0505
# Episode 56: Total Reward = 7, Epsilon = 0.0486
# Episode 57: Total Reward = 7, Epsilon = 0.0466
# Episode 58: Total Reward = 7, Epsilon = 0.0448
# Episode 59: Total Reward = 7, Epsilon = 0.0430
# Episode 60: Total Reward = 7, Epsilon = 0.0413
# Episode 61: Total Reward = 7, Epsilon = 0.0397
# Episode 62: Total Reward = 7, Epsilon = 0.0381
# Episode 63: Total Reward = 7, Epsilon = 0.0366
# Episode 64: Total Reward = 7, Epsilon = 0.0352
# Episode 65: Total Reward = 7, Epsilon = 0.0338
# Episode 66: Total Reward = 7, Epsilon = 0.0325
# Episode 67: Total Reward = 3, Epsilon = 0.0300
# Episode 68: Total Reward = 7, Epsilon = 0.0288
# Episode 69: Total Reward = 7, Epsilon = 0.0277
# Episode 70: Total Reward = 7, Epsilon = 0.0266
# Episode 71: Total Reward = 5, Epsilon = 0.0250
# Episode 72: Total Reward = 5, Epsilon = 0.0235
# Episode 73: Total Reward = 7, Epsilon = 0.0226
# Episode 74: Total Reward = 7, Epsilon = 0.0217
# Episode 75: Total Reward = 7, Epsilon = 0.0209
# Episode 76: Total Reward = 5, Epsilon = 0.0196
# Episode 77: Total Reward = 7, Epsilon = 0.0189
# Episode 78: Total Reward = 7, Epsilon = 0.0181
# Episode 79: Total Reward = 7, Epsilon = 0.0174
# Episode 80: Total Reward = 7, Epsilon = 0.0167
# Episode 81: Total Reward = 7, Epsilon = 0.0161
# Episode 82: Total Reward = 7, Epsilon = 0.0154
# Episode 83: Total Reward = 7, Epsilon = 0.0148
# Episode 84: Total Reward = 7, Epsilon = 0.0142
# Episode 85: Total Reward = 7, Epsilon = 0.0137
# Episode 86: Total Reward = 7, Epsilon = 0.0131
# Episode 87: Total Reward = 7, Epsilon = 0.0126
# Episode 88: Total Reward = 7, Epsilon = 0.0121
# Episode 89: Total Reward = 7, Epsilon = 0.0117
# Episode 90: Total Reward = 7, Epsilon = 0.0112
# Episode 91: Total Reward = 7, Epsilon = 0.0108
# Episode 92: Total Reward = 7, Epsilon = 0.0103
# Episode 93: Total Reward = 7, Epsilon = 0.0099
# Episode 94: Total Reward = 7, Epsilon = 0.0099
# Episode 95: Total Reward = 7, Epsilon = 0.0099
# Episode 96: Total Reward = 7, Epsilon = 0.0099
# Episode 97: Total Reward = 7, Epsilon = 0.0099
# Episode 98: Total Reward = 7, Epsilon = 0.0099
# Episode 99: Total Reward = 7, Epsilon = 0.0099
# Episode 100: Total Reward = 7, Epsilon = 0.0099
# Episode 101: Total Reward = 7, Epsilon = 0.0099
# Episode 102: Total Reward = 7, Epsilon = 0.0099
# Episode 103: Total Reward = 7, Epsilon = 0.0099
# Episode 104: Total Reward = 7, Epsilon = 0.0099
# Episode 105: Total Reward = 7, Epsilon = 0.0099
# Episode 106: Total Reward = 7, Epsilon = 0.0099
# Episode 107: Total Reward = 7, Epsilon = 0.0099
# Episode 108: Total Reward = 7, Epsilon = 0.0099
# Episode 109: Total Reward = 7, Epsilon = 0.0099
# Episode 110: Total Reward = 7, Epsilon = 0.0099
# Episode 111: Total Reward = 7, Epsilon = 0.0099
# Episode 112: Total Reward = 7, Epsilon = 0.0099
# Episode 113: Total Reward = 7, Epsilon = 0.0099
# Episode 114: Total Reward = 7, Epsilon = 0.0099
# Episode 115: Total Reward = 7, Epsilon = 0.0099
# Episode 116: Total Reward = 7, Epsilon = 0.0099
# Episode 117: Total Reward = 7, Epsilon = 0.0099
# Episode 118: Total Reward = 7, Epsilon = 0.0099
# Episode 119: Total Reward = 7, Epsilon = 0.0099
# Episode 120: Total Reward = 7, Epsilon = 0.0099
# Episode 121: Total Reward = 7, Epsilon = 0.0099
# Episode 122: Total Reward = 7, Epsilon = 0.0099
# Episode 123: Total Reward = 7, Epsilon = 0.0099
# Episode 124: Total Reward = 7, Epsilon = 0.0099
# Episode 125: Total Reward = 7, Epsilon = 0.0099
# Episode 126: Total Reward = 7, Epsilon = 0.0099
# Episode 127: Total Reward = 7, Epsilon = 0.0099
# Episode 128: Total Reward = 7, Epsilon = 0.0099
# Episode 129: Total Reward = 7, Epsilon = 0.0099
# Episode 130: Total Reward = 7, Epsilon = 0.0099
# Episode 131: Total Reward = 7, Epsilon = 0.0099
# Episode 132: Total Reward = 7, Epsilon = 0.0099
# Episode 133: Total Reward = 7, Epsilon = 0.0099
# Episode 134: Total Reward = 7, Epsilon = 0.0099
# Episode 135: Total Reward = 7, Epsilon = 0.0099
# Episode 136: Total Reward = 7, Epsilon = 0.0099
# Episode 137: Total Reward = 7, Epsilon = 0.0099
# Episode 138: Total Reward = 7, Epsilon = 0.0099
# Episode 139: Total Reward = 7, Epsilon = 0.0099
# Episode 140: Total Reward = 7, Epsilon = 0.0099
# Episode 141: Total Reward = 7, Epsilon = 0.0099
# Episode 142: Total Reward = 7, Epsilon = 0.0099
# Episode 143: Total Reward = 7, Epsilon = 0.0099
# Episode 144: Total Reward = 7, Epsilon = 0.0099
# Episode 145: Total Reward = 7, Epsilon = 0.0099
# Episode 146: Total Reward = 7, Epsilon = 0.0099
# Episode 147: Total Reward = 7, Epsilon = 0.0099
# Episode 148: Total Reward = 7, Epsilon = 0.0099
# Episode 149: Total Reward = 7, Epsilon = 0.0099
# Episode 150: Total Reward = 7, Epsilon = 0.0099
# Episode 151: Total Reward = 7, Epsilon = 0.0099
# Episode 152: Total Reward = 7, Epsilon = 0.0099
# Episode 153: Total Reward = 7, Epsilon = 0.0099
# Episode 154: Total Reward = 7, Epsilon = 0.0099
# Episode 155: Total Reward = 7, Epsilon = 0.0099
# Episode 156: Total Reward = 7, Epsilon = 0.0099
# Episode 157: Total Reward = 7, Epsilon = 0.0099
# Episode 158: Total Reward = 7, Epsilon = 0.0099
# Episode 159: Total Reward = 7, Epsilon = 0.0099
# Episode 160: Total Reward = 7, Epsilon = 0.0099
# Episode 161: Total Reward = 7, Epsilon = 0.0099
# Episode 162: Total Reward = 7, Epsilon = 0.0099
# Episode 163: Total Reward = 7, Epsilon = 0.0099
# Episode 164: Total Reward = 7, Epsilon = 0.0099
# Episode 165: Total Reward = 7, Epsilon = 0.0099
# Episode 166: Total Reward = 7, Epsilon = 0.0099
# Episode 167: Total Reward = 7, Epsilon = 0.0099
# Episode 168: Total Reward = 7, Epsilon = 0.0099
# Episode 169: Total Reward = 7, Epsilon = 0.0099
# Episode 170: Total Reward = 7, Epsilon = 0.0099
# Episode 171: Total Reward = 7, Epsilon = 0.0099
# Episode 172: Total Reward = 7, Epsilon = 0.0099
# Episode 173: Total Reward = 7, Epsilon = 0.0099
# Episode 174: Total Reward = 7, Epsilon = 0.0099
# Episode 175: Total Reward = 7, Epsilon = 0.0099
# Episode 176: Total Reward = 7, Epsilon = 0.0099
# Episode 177: Total Reward = 7, Epsilon = 0.0099
# Episode 178: Total Reward = 7, Epsilon = 0.0099
# Episode 179: Total Reward = 7, Epsilon = 0.0099
# Episode 180: Total Reward = 7, Epsilon = 0.0099
# Episode 181: Total Reward = 7, Epsilon = 0.0099
# Episode 182: Total Reward = 7, Epsilon = 0.0099
# Episode 183: Total Reward = 7, Epsilon = 0.0099
# Episode 184: Total Reward = 7, Epsilon = 0.0099
# Episode 185: Total Reward = 7, Epsilon = 0.0099
# Episode 186: Total Reward = 7, Epsilon = 0.0099
# Episode 187: Total Reward = 7, Epsilon = 0.0099
# Episode 188: Total Reward = 7, Epsilon = 0.0099
# Episode 189: Total Reward = 7, Epsilon = 0.0099
# Episode 190: Total Reward = 7, Epsilon = 0.0099
# Episode 191: Total Reward = 7, Epsilon = 0.0099
# Episode 192: Total Reward = 7, Epsilon = 0.0099
# Episode 193: Total Reward = 7, Epsilon = 0.0099
# Episode 194: Total Reward = 7, Epsilon = 0.0099
# Episode 195: Total Reward = 7, Epsilon = 0.0099
# Episode 196: Total Reward = 7, Epsilon = 0.0099
# Episode 197: Total Reward = 7, Epsilon = 0.0099
# Episode 198: Total Reward = 7, Epsilon = 0.0099
# Episode 199: Total Reward = 7, Epsilon = 0.0099
# Episode 200: Total Reward = 7, Epsilon = 0.0099
# Episode 201: Total Reward = 7, Epsilon = 0.0099
# Episode 202: Total Reward = 7, Epsilon = 0.0099
# Episode 203: Total Reward = 7, Epsilon = 0.0099
# Episode 204: Total Reward = 7, Epsilon = 0.0099
# Episode 205: Total Reward = 7, Epsilon = 0.0099
# Episode 206: Total Reward = 7, Epsilon = 0.0099
# Episode 207: Total Reward = 7, Epsilon = 0.0099
# Episode 208: Total Reward = 7, Epsilon = 0.0099
# Episode 209: Total Reward = 7, Epsilon = 0.0099
# Episode 210: Total Reward = 7, Epsilon = 0.0099
# Episode 211: Total Reward = 7, Epsilon = 0.0099
# Episode 212: Total Reward = 7, Epsilon = 0.0099
# Episode 213: Total Reward = 7, Epsilon = 0.0099
# Episode 214: Total Reward = 7, Epsilon = 0.0099
# Episode 215: Total Reward = 7, Epsilon = 0.0099
# Episode 216: Total Reward = 7, Epsilon = 0.0099
# Episode 217: Total Reward = 7, Epsilon = 0.0099
# Episode 218: Total Reward = 7, Epsilon = 0.0099
# Episode 219: Total Reward = 7, Epsilon = 0.0099
# Episode 220: Total Reward = 7, Epsilon = 0.0099
# Episode 221: Total Reward = 7, Epsilon = 0.0099
# Episode 222: Total Reward = 7, Epsilon = 0.0099
# Episode 223: Total Reward = 7, Epsilon = 0.0099
# Episode 224: Total Reward = 7, Epsilon = 0.0099
# Episode 225: Total Reward = 7, Epsilon = 0.0099
# Episode 226: Total Reward = 7, Epsilon = 0.0099
# Episode 227: Total Reward = 7, Epsilon = 0.0099
# Episode 228: Total Reward = 7, Epsilon = 0.0099
# Episode 229: Total Reward = 7, Epsilon = 0.0099
# Episode 230: Total Reward = 7, Epsilon = 0.0099
# Episode 231: Total Reward = 7, Epsilon = 0.0099
# Episode 232: Total Reward = 7, Epsilon = 0.0099
# Episode 233: Total Reward = 7, Epsilon = 0.0099
# Episode 234: Total Reward = 7, Epsilon = 0.0099
# Episode 235: Total Reward = 7, Epsilon = 0.0099
# Episode 236: Total Reward = 7, Epsilon = 0.0099
# Episode 237: Total Reward = 7, Epsilon = 0.0099
# Episode 238: Total Reward = 7, Epsilon = 0.0099
# Episode 239: Total Reward = 7, Epsilon = 0.0099
# Episode 240: Total Reward = 7, Epsilon = 0.0099
# Episode 241: Total Reward = 7, Epsilon = 0.0099
# Episode 242: Total Reward = 7, Epsilon = 0.0099
# Episode 243: Total Reward = 7, Epsilon = 0.0099
# Episode 244: Total Reward = 7, Epsilon = 0.0099
# Episode 245: Total Reward = 7, Epsilon = 0.0099
# Episode 246: Total Reward = 7, Epsilon = 0.0099
# Episode 247: Total Reward = 7, Epsilon = 0.0099
# Episode 248: Total Reward = 5, Epsilon = 0.0099
# Episode 249: Total Reward = 7, Epsilon = 0.0099
# Episode 250: Total Reward = 7, Epsilon = 0.0099
# Episode 251: Total Reward = 7, Epsilon = 0.0099
# Episode 252: Total Reward = 7, Epsilon = 0.0099
# Episode 253: Total Reward = 7, Epsilon = 0.0099
# Episode 254: Total Reward = 7, Epsilon = 0.0099
# Episode 255: Total Reward = 7, Epsilon = 0.0099
# Episode 256: Total Reward = 7, Epsilon = 0.0099
# Episode 257: Total Reward = 7, Epsilon = 0.0099
# Episode 258: Total Reward = 7, Epsilon = 0.0099
# Episode 259: Total Reward = 7, Epsilon = 0.0099
# Episode 260: Total Reward = 7, Epsilon = 0.0099
# Episode 261: Total Reward = 7, Epsilon = 0.0099
# Episode 262: Total Reward = 7, Epsilon = 0.0099
# Episode 263: Total Reward = 5, Epsilon = 0.0099
# Episode 264: Total Reward = 7, Epsilon = 0.0099
# Episode 265: Total Reward = 7, Epsilon = 0.0099
# Episode 266: Total Reward = 7, Epsilon = 0.0099
# Episode 267: Total Reward = 7, Epsilon = 0.0099
# Episode 268: Total Reward = 7, Epsilon = 0.0099
# Episode 269: Total Reward = 7, Epsilon = 0.0099
# Episode 270: Total Reward = 7, Epsilon = 0.0099
# Episode 271: Total Reward = 7, Epsilon = 0.0099
# Episode 272: Total Reward = 7, Epsilon = 0.0099
# Episode 273: Total Reward = 7, Epsilon = 0.0099
# Episode 274: Total Reward = 7, Epsilon = 0.0099
# Episode 275: Total Reward = 7, Epsilon = 0.0099
# Episode 276: Total Reward = 7, Epsilon = 0.0099
# Episode 277: Total Reward = 7, Epsilon = 0.0099
# Episode 278: Total Reward = 7, Epsilon = 0.0099
# Episode 279: Total Reward = 7, Epsilon = 0.0099
# Episode 280: Total Reward = 7, Epsilon = 0.0099
# Episode 281: Total Reward = 7, Epsilon = 0.0099
# Episode 282: Total Reward = 7, Epsilon = 0.0099
# Episode 283: Total Reward = 7, Epsilon = 0.0099
# Episode 284: Total Reward = 7, Epsilon = 0.0099
# Episode 285: Total Reward = 7, Epsilon = 0.0099
# Episode 286: Total Reward = 7, Epsilon = 0.0099
# Episode 287: Total Reward = 7, Epsilon = 0.0099
# Episode 288: Total Reward = 7, Epsilon = 0.0099
# Episode 289: Total Reward = 7, Epsilon = 0.0099
# Episode 290: Total Reward = 7, Epsilon = 0.0099
# Episode 291: Total Reward = 7, Epsilon = 0.0099
# Episode 292: Total Reward = 7, Epsilon = 0.0099
# Episode 293: Total Reward = 7, Epsilon = 0.0099
# Episode 294: Total Reward = 7, Epsilon = 0.0099
# Episode 295: Total Reward = 7, Epsilon = 0.0099
# Episode 296: Total Reward = 7, Epsilon = 0.0099
# Episode 297: Total Reward = 7, Epsilon = 0.0099
# Episode 298: Total Reward = 7, Epsilon = 0.0099
# Episode 299: Total Reward = 7, Epsilon = 0.0099
